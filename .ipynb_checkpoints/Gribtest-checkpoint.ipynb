# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import cartopy.crs as ccrs
import cartopy
import pygrib
#from mpl_toolkits.basemap import Basemap, addcyclic


# %matplotlib inline

# %% [raw]
# ax = plt.axes(projection=ccrs.PlateCarree())
# ax.coastlines()
#
# plt.show()

# %%
#ds = xr.open_dataset('blend.t06z.master.f001.co.grib2', engine='pynio')

# %%
filename = 'blend.t06z.master.f001.co.grib2'
#use forecast hours (f001)

gr = pygrib.open(filename)
g = gr.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65807/260934255.py in <module>
#       2 #use forecast hours (f001)
#       3
# ----> 4 gr = pygrib.open(filename)
#       5 g = gr.read()
#
# NameError: name 'pygrib' is not defined

# %%
for g in gr:
    print(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65807/1717738361.py in <module>
# ----> 1 for g in gr:
#       2     print(g)
#
# NameError: name 'gr' is not defined

# %%
pop = gr[73] #prob of precipitation at every grid cell (should be num between 0-100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65807/3845454512.py in <module>
# ----> 1 pop = gr[73] #prob of precipitation at every grid cell (should be num between 0-100)
#
# NameError: name 'gr' is not defined

# %%
popval = pop.values

# %%
print(popval)
print(len(popval))
# Out:
# [[7.6 7.6 7.6 ... 8.  8.  8. ]
#  [7.6 8.  7.6 ... 8.  8.  8. ]
#  [8.  7.6 7.6 ... 8.  8.  8. ]
#  ...
#  [9.6 9.6 9.6 ... 7.2 5.6 6. ]
#  [9.6 9.6 9.6 ... 5.6 6.  6.8]
#  [9.6 9.6 9.6 ... 6.  6.  6.8]]
# 1597

# %%
plt.imshow(t0)
# Out:
# 1:Apparent temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 1 hrs:from 202005190600

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7313/4076784564.py in <module>
# ----> 1 temperatures.t2m[0].plot(cmap=plt.cm.coolwarm)
#
# AttributeError: 'list' object has no attribute 't2m'

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(resolution='10m')
plot = gr.t2m[0].plot(cmap=plt.cm.coolwarm, transform=ccrs.PlateCarree(), cbar_kwargs={'shrink':0.6})
plt.title('Map')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7313/435180389.py in <module>
#       2 ax = plt.axes(projection=ccrs.Robinson())
#       3 ax.coastlines(resolution='10m')
# ----> 4 plot = gr.t2m[0].plot(cmap=plt.cm.coolwarm, transform=ccrs.PlateCarree(), cbar_kwargs={'shrink':0.6})
#       5 plt.title('Map')
#
# AttributeError: 'pygrib._pygrib.open' object has no attribute 't2m'

# %%
data:image/png;base64,...
